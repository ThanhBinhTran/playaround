# %%
#Run with Python 3

import pandas as pd
import numpy as np
import urllib.request
import shutil
import re
import os
import pathlib
import argparse
import pdb
import threading
from bs4 import BeautifulSoup

# %%
def generate_ID():
    partIDs = range (1, 5, 1)
    fullIDs =[]
    for item in partIDs:
        fullIDs.append( "02001{0:03d}".format(item))
        
    return pd.Series(fullIDs)
threshold = 100
def generate_ID(IDbegin):
    partIDs = range (IDbegin, IDbegin + threshold-1, 1)
    fullIDs =[]
    for item in partIDs:
        fullIDs.append( "02001{0:03d}".format(item))
    return pd.Series(fullIDs)

IDs = generate_ID(1)

for id in IDs:
    print (id)
    
link = "http://diemthi.hcm.edu.vn/Home/Show";
print (link)
# Out:
# 02001001
# 02001002
# 02001003
# 02001004
# 02001005
# 02001006
# 02001007
# 02001008
# 02001009
# 02001010
# 02001011
# 02001012
# 02001013
# 02001014
# 02001015
# 02001016
# 02001017
# 02001018
# 02001019
# 02001020
# 02001021
# 02001022
# 02001023
# 02001024
# 02001025
# 02001026
# 02001027
# 02001028
# 02001029
# 02001030
# 02001031
# 02001032
# 02001033
# 02001034
# 02001035
# 02001036
# 02001037
# 02001038
# 02001039
# 02001040
# 02001041
# 02001042
# 02001043
# 02001044
# 02001045
# 02001046
# 02001047
# 02001048
# 02001049
# 02001050
# 02001051
# 02001052
# 02001053
# 02001054
# 02001055
# 02001056
# 02001057
# 02001058
# 02001059
# 02001060
# 02001061
# 02001062
# 02001063
# 02001064
# 02001065
# 02001066
# 02001067
# 02001068
# 02001069
# 02001070
# 02001071
# 02001072
# 02001073
# 02001074
# 02001075
# 02001076
# 02001077
# 02001078
# 02001079
# 02001080
# 02001081
# 02001082
# 02001083
# 02001084
# 02001085
# 02001086
# 02001087
# 02001088
# 02001089
# 02001090
# 02001091
# 02001092
# 02001093
# 02001094
# 02001095
# 02001096
# 02001097
# 02001098
# 02001099
# http://diemthi.hcm.edu.vn/Home/Show

# %%
import pycurl
from io import BytesIO
try:
    # python 3
    from urllib.parse import urlencode
except ImportError:
    # python 2
    from urllib import urlencode
    
buffer = BytesIO()
c = pycurl.Curl()
c.setopt(c.URL, links)
c.setopt(c.WRITEDATA, buffer)

post_data = {'sobaodanh': '02002001'}
# Form data must be provided already urlencoded.
postfields = urlencode(post_data)
# Sets request method to POST,
# Content-Type header to application/x-www-form-urlencoded
# and data to send in request body.
c.setopt(c.POSTFIELDS, postfields)

c.perform()
c.close()

body = buffer.getvalue()
# Body is a byte string.
# We have to know the encoding in order to print it to a text file
# such as standard output.
print(buffer)
# Out:
# <_io.BytesIO object at 0x000002420C5324C8>

# %%
import pycurl
import csv
from io import BytesIO

try:
    # python 3
    from urllib.parse import urlencode
except ImportError:
    # python 2
    from urllib import urlencode

def get_data(sbd):
    buffer = BytesIO()
    print(sbd)
    c = pycurl.Curl()
    c.setopt(c.URL, link)
    c.setopt(c.WRITEDATA, buffer)

    post_data = {'sobaodanh': sbd}
    # Form data must be provided already urlencoded.
    postfields = urlencode(post_data)
    # Sets request method to POST,
    # Content-Type header to application/x-www-form-urlencoded
    # and data to send in request body.
    c.setopt(c.POSTFIELDS, postfields)

    c.perform()
    c.close()
    #print(buffer.getvalue().decode())
    return buffer.getvalue()

def parse_line(body):
    webdata = BeautifulSoup(body, "lxml")
    linestr =[]
    #print(webdata)
    if webdata != -1:
        rows = webdata.find_all('tr')
        Info = rows[1].find_all('td')
        for info in Info:
            linestr.append(info.text.strip())
    #print (linestr)
    return linestr

# As long as the file is opened in binary mode, both Python 2 and Python 3
# can write response body to it without decoding.
f = open("score.csv", 'w', newline='', encoding="utf-8")
writer = csv.writer(f, delimiter=",")
writer.writerow(['Name','date of birth','results'])
for sbd in IDs:
    body = get_data(sbd)
    linedata = parse_line(body)
    writer.writerow(linedata)
f.close()
print ("DONE")
# Out:
# 02001001
# 02001002
# 02001003
# 02001004
# 02001005
# 02001006
# 02001007
# 02001008
# 02001009
# 02001010
# 02001011
# 02001012
# 02001013
# 02001014
# 02001015
# 02001016
# 02001017
# 02001018
# 02001019
# 02001020
# 02001021
# 02001022
# 02001023
# 02001024
# 02001025
# 02001026
# 02001027
# 02001028
# 02001029
# 02001030
# 02001031
# 02001032
# 02001033
# 02001034
# 02001035
# 02001036
# 02001037
# 02001038
# 02001039
# 02001040
# 02001041
# 02001042
# 02001043
# 02001044
# 02001045
# 02001046
# 02001047
# 02001048
# 02001049
# 02001050
# 02001051
# 02001052
# 02001053
# 02001054
# 02001055
# 02001056
# 02001057
# 02001058
# 02001059
# 02001060
# 02001061
# 02001062
# 02001063
# 02001064
# 02001065
# 02001066
# 02001067
# 02001068
# 02001069
# 02001070
# 02001071
# 02001072
# 02001073
# 02001074
# 02001075
# 02001076
# 02001077
# 02001078
# 02001079
# 02001080
# 02001081
# 02001082
# 02001083
# 02001084
# 02001085
# 02001086
# 02001087
# 02001088
# 02001089
# 02001090
# 02001091
# 02001092
# 02001093
# 02001094
# 02001095
# 02001096
# 02001097
# 02001098
# 02001099
# DONE

# %%
# Parallelizing using Pool.apply()
import csv

threshold = 100
inputrange = range(1,4*threshold, threshold)
#for inpt in inputrange:
#    print (inpt)

def get_score_parallel(IDstart):
    IDs = generate_ID(IDstart)
    filename = "result{0:06d}.csv".format(IDstart)
    f = open(filename, 'w', newline='', encoding="utf-8")
    print (filename)
    writer = csv.writer(f, delimiter=",")
    writer.writerow(['Name','date of birth','results'])
    for sbd in IDs:
        body = get_data(sbd)
        linedata = parse_line(body)
        writer.writerow(linedata)
        #writer.writerow(sbd)
    f.close()

from multiprocessing import Pool
import multiprocessing as mp

def f(x):
    return x*x

if __name__ == '__main__':
    with Pool(mp.cpu_count()) as p:
        print(p.map(f, [1, 2, 3]))
#get_score_parallel(1)
# Step 1: Init multiprocessing.Pool()
#pool = mp.Pool(mp.cpu_count())

# Step 2: `pool.map` the `get_score_parallel()`
#pool.map_async(get_score_parallel, [1,20,30,40])

# Step 3: Don't forget to close
#pool.close() 
print ("DONE")

# %%
from multiprocessing import Pool
import multiprocessing as mp

def f(x):
    return x*x

if __name__ == '__main__':
    with Pool(mp.cpu_count()) as p:
        print(p.map(f, [1, 2, 3]))

# %%
# Parallelizing using Pool.apply()
import csv
from multiprocessing import Pool
import multiprocessing as mp
import os
import pandas as pd
from io import BytesIO
import pycurl


try:
    # python 3
    from urllib.parse import urlencode
except ImportError:
    # python 2
    from urllib import urlencode

threshold = 100
def generate_ID(IDbegin):
    partIDs = range (IDbegin, IDbegin + threshold-1, 1)
    fullIDs =[]
    for item in partIDs:
        fullIDs.append( "02001{0:03d}".format(item))
    return pd.Series(fullIDs)

inputrange = range(1,4*threshold, threshold)
#for inpt in inputrange:
#    print (inpt)


def get_data(sbd):
    buffer = BytesIO()
    print(sbd)
    c = pycurl.Curl()
    c.setopt(c.URL, link)
    c.setopt(c.WRITEDATA, buffer)

    post_data = {'sobaodanh': sbd}
    # Form data must be provided already urlencoded.
    postfields = urlencode(post_data)
    # Sets request method to POST,
    # Content-Type header to application/x-www-form-urlencoded
    # and data to send in request body.
    c.setopt(c.POSTFIELDS, postfields)

    c.perform()
    c.close()
    #print(buffer.getvalue().decode())
    return buffer.getvalue()

def parse_line(body):
    webdata = BeautifulSoup(body, "lxml")
    linestr =[]
    #print(webdata)
    if webdata != -1:
        rows = webdata.find_all('tr')
        Info = rows[1].find_all('td')
        for info in Info:
            linestr.append(info.text.strip())
    #print (linestr)
    return linestr

def get_score_parallel(IDstart):
    IDs = generate_ID(IDstart)
    filename = "result{0:06d}.csv".format(IDstart)
    f = open(filename, 'w', newline='', encoding="utf-8")
    print (filename)
    writer = csv.writer(f, delimiter=",")
    writer.writerow(['Name','date of birth','results'])
    for sbd in IDs:
        body = get_data(sbd)
        linedata = parse_line(body)
        writer.writerow(linedata)
    f.close()

print ("START", os.getpid())

if __name__ == '__main__':
    with Pool(mp.cpu_count()) as p:
        p.map(get_score_parallel, inputrange)
print ("DONE")
